# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# merging data into single file

all_data = pd.DataFrame()

f=[file for file in os.listdir(r'C:\Users\divya\Downloads\sales\Sales_Data/')]
# Assuming `f` contains the list of file names
for file in f:
    d = pd.read_csv(r'C:\Users\divya\Downloads\sales\Sales_Data/' + file)
    all_data = pd.concat([all_data, d])

all_data.to_csv("all_data.csv",index=False)

# %%
a=pd.read_csv(r"all_data.csv")
a.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
a.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 186845    False
# 186846    False
# 186847    False
# 186848    False
# 186849    False
# Length: 186850, dtype: bool

# %%
a[a.duplicated()]
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 31        176585  Bose SoundSport Headphones                 1       99.99
# 356          NaN                         NaN               NaN         NaN
# 735          NaN                         NaN               NaN         NaN
# 1149    Order ID                     Product  Quantity Ordered  Price Each
# 1155    Order ID                     Product  Quantity Ordered  Price Each
# ...          ...                         ...               ...         ...
# 186632  Order ID                     Product  Quantity Ordered  Price Each
# 186738  Order ID                     Product  Quantity Ordered  Price Each
# 186782    259296    Apple Airpods Headphones                 1         150
# 186785    259297    Lightning Charging Cable                 1       14.95
# 186826       NaN                         NaN               NaN         NaN
#
#             Order Date                   Purchase Address
# ...

# %%
a.drop_duplicates()
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
a.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
a.dropna()
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
a.drop_duplicates(inplace=True)

# %%
a
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
a.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
a.dropna(inplace=True)

# %%
# what was the best month for sales? How much we earned that month

import pandas as pd

# Assuming `a` is your DataFrame
a['Order Date'] = pd.to_datetime(a['Order Date'], errors='coerce')  # Convert 'Order Date' column to datetime format, handling errors
a['Month'] = a['Order Date'].dt.month  # Extract the month and assign it to a new column 'Month'

# Now the 'Month' column contains the month extracted from the 'Order Date' column

# %%
a.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered            object
# Price Each                  object
# Order Date          datetime64[ns]
# Purchase Address            object
# Month                      float64
# dtype: object

# %%
a.head(100)
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 0     176558        USB-C Charging Cable                2      11.95
# 2     176559  Bose SoundSport Headphones                1      99.99
# 3     176560                Google Phone                1        600
# 4     176560            Wired Headphones                1      11.99
# 5     176561            Wired Headphones                1      11.99
# ..       ...                         ...              ...        ...
# 97    176650    Lightning Charging Cable                1      14.95
# 98    176651                      iPhone                1        700
# 99    176652          LG Washing Machine                1      600.0
# 100   176653       AA Batteries (4-pack)                1       3.84
# 101   176654        USB-C Charging Cable                1      11.95
#
#              Order Date                          Purchase Address  Month
# ...

# %%
a=a.dropna(how='all')
a.dropna(axis=0,inplace=True)
a.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address  Month
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    4.0

# %%
# convert Quantity and price to Int
a['Quantity Ordered'] = pd.to_numeric(a['Quantity Ordered'], errors='coerce')
a['Price Each'] = pd.to_numeric(a['Price Each'], errors='coerce')
#a[['Quantity Ordered','Price Each']]=a[['Quantity Ordered','Price Each']].astype(int)

# %%
# Add a Sales column 
a['Sales']=a['Quantity Ordered']*a['Price Each']

# %%
a.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    4.0   11.99

# %%
#### which month has highest number of sales

# %%
a.groupby('Month').sum()['Sales'].plot(kind='line')
# Out:
# <AxesSubplot:xlabel='Month'>

# %% [markdown]
# ###What city has highest number of sales

# %%
a['city']=a['Purchase Address'].apply(lambda x:x.split(',')[1].strip() if len(x.split(',')) >= 2 else '')

# %%
a.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    4.0   11.99
#
#           city
# 0       Dallas
# 2       Boston
# 3  Los Angeles
# 4  Los Angeles
# 5  Los Angeles

# %%
### which city has highest number of Sales


a.groupby('city').sum()['Sales'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='city'>

# %%
# what time should we display advertisements to maximize likelihood of the customers buying product

a["Order Date"]=pd.to_datetime(a['Order Date'])
a["hour"]=a['Order Date'].dt.hour
a["minute"]=a['Order Date'].dt.minute
a.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001    4.0   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215    4.0   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001    4.0   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001    4.0   11.99
#
#           city  hour  minute
# 0       Dallas     8      46
# 2       Boston    22      30
# ...

# %%
### At what time highest numbers of orders are placed

hours = a["hour"].unique()

# Plot a bar graph for each hour
for hour in hours:
    data_hour = a[a['hour'] == hour]
    hour_counts = a['hour'].value_counts().sort_index()
hour_counts.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# what products are sold often together?

a["Grouped"]=a.groupby('Order ID')['Product'].transform(lambda x:','.join(x))

#a=a[['Order ID','Grouped']].drop_duplicates()
a.head(100)
# Out:
#     Order ID                     Product  Quantity Ordered  Price Each  \
# 0     176558        USB-C Charging Cable                 2       11.95
# 2     176559  Bose SoundSport Headphones                 1       99.99
# 3     176560                Google Phone                 1      600.00
# 4     176560            Wired Headphones                 1       11.99
# 5     176561            Wired Headphones                 1       11.99
# ..       ...                         ...               ...         ...
# 97    176650    Lightning Charging Cable                 1       14.95
# 98    176651                      iPhone                 1      700.00
# 99    176652          LG Washing Machine                 1      600.00
# 100   176653       AA Batteries (4-pack)                 1        3.84
# 101   176654        USB-C Charging Cable                 1       11.95
#
#              Order Date                          Purchase Address  Month  \
# ...

# %%
from itertools import combinations
from collections import Counter
c=Counter()
for row in a["Grouped"]:
    row_list=row.split(',')
    c.update(Counter(combinations(row_list,2)))
for key,value in c.most_common(10):
    print(key,value)
# Out:
# ('iPhone', 'Lightning Charging Cable') 2127
# ('Google Phone', 'USB-C Charging Cable') 2106
# ('iPhone', 'Wired Headphones') 987
# ('Google Phone', 'Wired Headphones') 943
# ('iPhone', 'Apple Airpods Headphones') 799
# ('Vareebadd Phone', 'USB-C Charging Cable') 773
# ('Google Phone', 'Bose SoundSport Headphones') 503
# ('USB-C Charging Cable', 'Wired Headphones') 446
# ('Vareebadd Phone', 'Wired Headphones') 327
# ('Lightning Charging Cable', 'Wired Headphones') 253

# %%
# What product sold the most ? 
a.head()
pg=a.groupby('Product')
QO=pg.sum()['Quantity Ordered']
products=[p for p, a in pg]
QO.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product'>

# %%
prices = a.groupby('Product').mean()['Price Each']

fig,ax1=plt.subplots()
ax2=ax1.twinx()
ax1.bar(products,QO,color='g')
ax2.plot(products,prices,'b-')
ax1.set_xlabel('Product Name')
ax1.set_ylabel('Quantity Ordered', color='g')
ax2.set_ylabel('price($)',color='b')
ax1.set_xticklabels(products,rotation='vertical',size=8)
plt.show()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_44108\647173566.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(products,rotation='vertical',size=8)
